# %% [markdown]
# ##aimindtool

# %%
# !pip install crewai
# !pip install crewai_tools
# !pip install 'crewai[tools]'
# !pip install minds-sdk
# !pip install uv
# !uv add minds-sdk
# !pip install mindsdb-sdk
# Out:
# ...
# error: No `pyproject.toml` found in current directory or any parent directory
# ...

# %%
from crewai_tools import AIMindTool

# %%
import os
os.environ['MINDS_API_KEY']="mdb_2a9tytWBsSgiwY15SJDoEDRNlXv6uX0TPs8EjCbrYpan"

# %%
from minds.client import Client
from minds.datasources import DatabaseConfig

mariadb_config = DatabaseConfig(
    name='kavin',
    description='Local MariaDB instance with posts and users tables',
    engine='mariadb',
    connection_data={
        'user': 'root',
        'password': 'Ispl@2025',
        'host': '127.0.0.1',      # Use your IP address if running outside the same process
        'port': 3306,
        'database': 'kavin'
    },
    tables=['posts', 'users']
)

# %%
client=Client(api_key=os.environ['MINDS_API_KEY'])

# %%
import urllib.parse
password = urllib.parse.quote_plus("Ispl@2025")
DATABASE_URI = f"mysql+pymysql://kavin:{password}@192.168.1.197:3306/kavin"

# %%
from crewai_tools import AIMindTool

# Create MindsDB configuration
aimind_tool = AIMindTool(
    api_key="mdb_2a9tytWBsSgiwY15SJDoEDRNlXv6uX0TPs8EjCbrYpan",
    datasources=[
        {
            "name": "kavin_db",  # Add a unique name for the datasource
            "description": "Local MariaDB - kavin database",
            "engine": "mysql",
            "connection_data": {
                "user": "kavin",
                "password": "Ispl@2025",  # Use unencoded password here
                "host": "192.168.1.197",
                "port": 3306,
                "database": "kavin"
            },
            "tables": ["users", "posts"]
        }
    ]
)

# Test the tool with a simple query
result = aimind_tool.run("How many user`s have posted more than 3 posts?")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ObjectNotFound                            Traceback (most recent call last)
# File ~/Desktop/Frappe_bot/.venv/lib/python3.12/site-packages/minds/minds.py:292, in Minds._check_datasource(self, ds)
#     291 try:
# --> 292     self.client.datasources.get(ds.name)
#     293 except exc.ObjectNotFound:
#
# File ~/Desktop/Frappe_bot/.venv/lib/python3.12/site-packages/minds/datasources/datasources.py:91, in Datasources.get(self, name)
#      84 """
#      85 Get datasource by name
#      86
#      87 :param name: name of datasource
#      88 :return: datasource object
#      89 """
# ---> 91 data = self.api.get(f'/datasources/{name}').json()
#      93 # TODO skip not sql skills
#
# File ~/Desktop/Frappe_bot/.venv/lib/python3.12/site-packages/minds/rest_api.py:37, in RestAPI.get(self, url)
#      35 resp = requests.get(self.base_url + url, headers=self._headers())
# ---> 37 _raise_for_status(resp)
# ...

# %%
import mysql.connector

try:
    connection = mysql.connector.connect(
        host="192.168.1.197",
        user="kavin",
        password="Ispl@2025",
        database="kavin"
    )
    print("Connection successful!")
    connection.close()
except mysql.connector.Error as e:
    print(f"Error: {e}")
# Out:
# Connection successful!
