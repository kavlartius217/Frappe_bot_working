# %% [markdown]
# ##my sql rag

# %%
#import os
#os.environ['OPENAI_API_KEY']=""

# %%
# %pip install crewai
# %pip install crewai_tools
# %pip install 'crewai[tools]'
# Out:
# Requirement already satisfied: crewai in ./.venv/lib/python3.12/site-packages (0.130.0)
# Requirement already satisfied: appdirs>=1.4.4 in ./.venv/lib/python3.12/site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in ./.venv/lib/python3.12/site-packages (from crewai) (4.10.0)
# Requirement already satisfied: blinker>=1.9.0 in ./.venv/lib/python3.12/site-packages (from crewai) (1.9.0)
# Requirement already satisfied: chromadb>=0.5.23 in ./.venv/lib/python3.12/site-packages (from crewai) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in ./.venv/lib/python3.12/site-packages (from crewai) (8.2.1)
# Requirement already satisfied: instructor>=1.3.3 in ./.venv/lib/python3.12/site-packages (from crewai) (1.8.3)
# Requirement already satisfied: json-repair>=0.25.2 in ./.venv/lib/python3.12/site-packages (from crewai) (0.46.2)
# Requirement already satisfied: json5>=0.10.0 in ./.venv/lib/python3.12/site-packages (from crewai) (0.12.0)
# Requirement already satisfied: jsonref>=1.1.0 in ./.venv/lib/python3.12/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm==1.72.0 in ./.venv/lib/python3.12/site-packages (from crewai) (1.72.0)
# Requirement already satisfied: onnxruntime==1.22.0 in ./.venv/lib/python3.12/site-packages (from crewai) (1.22.0)
# Requirement already satisfied: openai>=1.13.3 in ./.venv/lib/python3.12/site-packages (from crewai) (1.86.0)
# Requirement already satisfied: openpyxl>=3.1.5 in ./.venv/lib/python3.12/site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.30.0 in ./.venv/lib/python3.12/site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.30.0 in ./.venv/lib/python3.12/site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in ./.venv/lib/python3.12/site-packages (from crewai) (1.34.1)
# Requirement already satisfied: pdfplumber>=0.11.4 in ./.venv/lib/python3.12/site-packages (from crewai) (0.11.7)
# Requirement already satisfied: pydantic>=2.4.2 in ./.venv/lib/python3.12/site-packages (from crewai) (2.11.5)
# Requirement already satisfied: python-dotenv>=1.0.0 in ./.venv/lib/python3.12/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: pyvis>=0.3.2 in ./.venv/lib/python3.12/site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in ./.venv/lib/python3.12/site-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tokenizers>=0.20.3 in ./.venv/lib/python3.12/site-packages (from crewai) (0.20.3)
# Requirement already satisfied: tomli-w>=1.1.0 in ./.venv/lib/python3.12/site-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in ./.venv/lib/python3.12/site-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in ./.venv/lib/python3.12/site-packages (from crewai) (0.7.12)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai) (3.12.12)
# Requirement already satisfied: httpx>=0.23.0 in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai) (4.24.0)
# Requirement already satisfied: tiktoken>=0.7.0 in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai) (0.9.0)
# Requirement already satisfied: coloredlogs in ./.venv/lib/python3.12/site-packages (from onnxruntime==1.22.0->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in ./.venv/lib/python3.12/site-packages (from onnxruntime==1.22.0->crewai) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in ./.venv/lib/python3.12/site-packages (from onnxruntime==1.22.0->crewai) (2.3.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.12/site-packages (from onnxruntime==1.22.0->crewai) (24.2)
# Requirement already satisfied: protobuf in ./.venv/lib/python3.12/site-packages (from onnxruntime==1.22.0->crewai) (5.29.5)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from onnxruntime==1.22.0->crewai) (1.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.72.0->crewai) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.0->crewai) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.0->crewai) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.0->crewai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.0->crewai) (0.25.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.4.2->crewai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.4.2->crewai) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.4.2->crewai) (0.4.1)
# Requirement already satisfied: cryptography>=43.0.1 in ./.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (45.0.4)
# Requirement already satisfied: pyjwt>=2.8.0 in ./.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: requests>=2.32.3 in ./.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (2.32.4)
# Requirement already satisfied: urllib3>=2.2.3 in ./.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai) (1.20.1)
# Requirement already satisfied: idna>=2.0 in ./.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp->litellm==1.72.0->crewai) (3.10)
# Requirement already satisfied: build>=1.0.3 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.34.3)
# Requirement already satisfied: posthog>=2.4.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (3.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.55b1)
# Requirement already satisfied: pypika>=0.48.9 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (9.1.2)
# Requirement already satisfied: PyYAML>=6.0.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./.venv/lib/python3.12/site-packages (from tokenizers>=0.20.3->crewai) (0.33.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (1.1.3)
# Requirement already satisfied: pyproject_hooks in ./.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in ./.venv/lib/python3.12/site-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in ./.venv/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai) (0.45.3)
# Requirement already satisfied: anyio<5,>=3.6.2 in ./.venv/lib/python3.12/site-packages (from starlette<0.46.0,>=0.40.0->fastapi>=0.95.2->chromadb>=0.5.23->crewai) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi>=0.95.2->chromadb>=0.5.23->crewai) (1.3.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm==1.72.0->crewai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm==1.72.0->crewai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.72.0->crewai) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm==1.72.0->crewai) (3.23.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in ./.venv/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in ./.venv/lib/python3.12/site-packages (from instructor>=1.3.3->crewai) (0.8.2)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.32.3->auth0-python>=4.7.1->crewai) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (2.19.1)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Requirement already satisfied: six>=1.9.0 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: et-xmlfile in ./.venv/lib/python3.12/site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.30.0->crewai) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.55b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.8.1)
# Requirement already satisfied: pdfminer.six==20250506 in ./.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (20250506)
# Requirement already satisfied: Pillow>=9.1 in ./.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in ./.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: monotonic>=1.5 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: ipython>=5.3.0 in ./.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (9.3.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in ./.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in ./.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai) (3.5)
# Requirement already satisfied: decorator in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.51)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: httptools>=0.6.3 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in ./.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime==1.22.0->crewai) (10.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy->onnxruntime==1.22.0->crewai) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: crewai_tools in ./.venv/lib/python3.12/site-packages (0.47.1)
# Requirement already satisfied: chromadb>=0.4.22 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (0.5.23)
# Requirement already satisfied: click>=8.1.8 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (8.2.1)
# Requirement already satisfied: crewai>=0.126.0 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (0.130.0)
# Requirement already satisfied: docker>=7.1.0 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (7.1.0)
# Requirement already satisfied: embedchain>=0.1.114 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (0.1.128)
# Requirement already satisfied: lancedb>=0.5.4 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (0.23.0)
# Requirement already satisfied: openai>=1.12.0 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (1.86.0)
# Requirement already satisfied: pydantic>=2.6.1 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (2.11.5)
# Requirement already satisfied: pyright>=1.1.350 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (1.1.402)
# Requirement already satisfied: pytube>=15.0.0 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (15.0.0)
# Requirement already satisfied: requests>=2.31.0 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (2.32.4)
# Requirement already satisfied: tiktoken>=0.8.0 in ./.venv/lib/python3.12/site-packages (from crewai_tools) (0.9.0)
# Requirement already satisfied: build>=1.0.3 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.22->crewai_tools) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (2.3.0)
# Requirement already satisfied: posthog>=2.4.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (3.25.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (4.14.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (0.55b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (1.34.1)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (7.7.0)
# Requirement already satisfied: importlib-resources in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (9.1.2)
# Requirement already satisfied: PyYAML>=6.0.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.12/site-packages (from chromadb>=0.4.22->crewai_tools) (13.9.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./.venv/lib/python3.12/site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai_tools) (0.33.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai_tools) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai_tools) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai_tools) (24.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb>=0.4.22->crewai_tools) (1.1.3)
# Requirement already satisfied: pyproject_hooks in ./.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb>=0.4.22->crewai_tools) (1.2.0)
# Requirement already satisfied: appdirs>=1.4.4 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (4.10.0)
# Requirement already satisfied: blinker>=1.9.0 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (1.9.0)
# Requirement already satisfied: instructor>=1.3.3 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (1.8.3)
# Requirement already satisfied: json-repair>=0.25.2 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (0.46.2)
# Requirement already satisfied: json5>=0.10.0 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (0.12.0)
# Requirement already satisfied: jsonref>=1.1.0 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (1.1.0)
# Requirement already satisfied: litellm==1.72.0 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (1.72.0)
# Requirement already satisfied: openpyxl>=3.1.5 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (3.1.5)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.30.0 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (1.34.1)
# Requirement already satisfied: pdfplumber>=0.11.4 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (0.11.7)
# Requirement already satisfied: python-dotenv>=1.0.0 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (1.1.0)
# Requirement already satisfied: pyvis>=0.3.2 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in ./.venv/lib/python3.12/site-packages (from crewai>=0.126.0->crewai_tools) (0.7.12)
# Requirement already satisfied: aiohttp in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai>=0.126.0->crewai_tools) (3.12.12)
# Requirement already satisfied: importlib-metadata>=6.8.0 in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai>=0.126.0->crewai_tools) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai>=0.126.0->crewai_tools) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in ./.venv/lib/python3.12/site-packages (from litellm==1.72.0->crewai>=0.126.0->crewai_tools) (4.24.0)
# Requirement already satisfied: coloredlogs in ./.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai_tools) (15.0.1)
# Requirement already satisfied: flatbuffers in ./.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai_tools) (25.2.10)
# Requirement already satisfied: protobuf in ./.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai_tools) (5.29.5)
# Requirement already satisfied: sympy in ./.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.22->crewai_tools) (1.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (0.25.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.6.1->crewai_tools) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.6.1->crewai_tools) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.6.1->crewai_tools) (0.4.1)
# Requirement already satisfied: cryptography>=43.0.1 in ./.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai>=0.126.0->crewai_tools) (45.0.4)
# Requirement already satisfied: pyjwt>=2.8.0 in ./.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai>=0.126.0->crewai_tools) (2.10.1)
# Requirement already satisfied: urllib3>=2.2.3 in ./.venv/lib/python3.12/site-packages (from auth0-python>=4.7.1->crewai>=0.126.0->crewai_tools) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (1.20.1)
# Requirement already satisfied: idna>=2.0 in ./.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (3.10)
# Requirement already satisfied: cffi>=1.14 in ./.venv/lib/python3.12/site-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai>=0.126.0->crewai_tools) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=43.0.1->auth0-python>=4.7.1->crewai>=0.126.0->crewai_tools) (2.22)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (1.16.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (4.13.4)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (0.1.44)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (0.3.25)
# Requirement already satisfied: langchain-cohere<0.4.0,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (0.3.5)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.1 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (0.3.25)
# Requirement already satisfied: langchain-openai<0.3.0,>=0.2.1 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (0.2.14)
# Requirement already satisfied: langsmith<0.4.0,>=0.3.18 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (0.3.45)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.54 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (0.1.107)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (5.6.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (0.7.7)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in ./.venv/lib/python3.12/site-packages (from embedchain>=0.1.114->crewai_tools) (2.0.41)
# Requirement already satisfied: Mako in ./.venv/lib/python3.12/site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai_tools) (1.3.10)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain>=0.1.114->crewai_tools) (2.7)
# Requirement already satisfied: cachetools in ./.venv/lib/python3.12/site-packages (from gptcache<0.2.0,>=0.1.43->embedchain>=0.1.114->crewai_tools) (5.5.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in ./.venv/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai_tools) (0.3.65)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in ./.venv/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai_tools) (0.3.8)
# Requirement already satisfied: cohere<6.0,>=5.5.6 in ./.venv/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (5.15.0)
# Requirement already satisfied: langchain-experimental<0.4.0,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (0.3.4)
# Requirement already satisfied: pandas>=1.4.3 in ./.venv/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (2.3.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in ./.venv/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (0.9.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in ./.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (1.11.1)
# Requirement already satisfied: httpx-sse==0.4.0 in ./.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (0.4.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (2.32.4.20250611)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.venv/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai_tools) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./.venv/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai_tools) (2.9.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai_tools) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai_tools) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai_tools) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai_tools) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai_tools) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./.venv/lib/python3.12/site-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai_tools) (0.23.0)
# Requirement already satisfied: anyio in ./.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai_tools) (4.9.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai_tools) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb>=0.4.22->crewai_tools) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.4.22->crewai_tools) (0.16.0)
# Requirement already satisfied: pytz>=2024.1 in ./.venv/lib/python3.12/site-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai_tools) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in ./.venv/lib/python3.12/site-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai_tools) (1.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.12.0->crewai_tools) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.12.0->crewai_tools) (0.8.2)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from openai>=1.12.0->crewai_tools) (1.3.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai_tools) (1.17.0)
# Requirement already satisfied: monotonic>=1.5 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai_tools) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai_tools) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.4.22->crewai_tools) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.31.0->crewai_tools) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.4.22->crewai_tools) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.4.22->crewai_tools) (2.19.1)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai_tools) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai_tools) (1.1.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in ./.venv/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb>=0.4.22->crewai_tools) (0.45.3)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm==1.72.0->crewai>=0.126.0->crewai_tools) (3.23.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in ./.venv/lib/python3.12/site-packages (from instructor>=1.3.3->crewai>=0.126.0->crewai_tools) (0.16)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb>=0.4.22->crewai_tools) (1.5.4)
# Requirement already satisfied: google-auth>=1.0.1 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai_tools) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai_tools) (1.8.0)
# Requirement already satisfied: requests-oauthlib in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai_tools) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai_tools) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.22->crewai_tools) (0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.22->crewai_tools) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.22->crewai_tools) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.22->crewai_tools) (0.6.1)
# Requirement already satisfied: deprecation in ./.venv/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai_tools) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in ./.venv/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai_tools) (20.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.4.22->crewai_tools) (0.1.2)
# Requirement already satisfied: et-xmlfile in ./.venv/lib/python3.12/site-packages (from openpyxl>=3.1.5->crewai>=0.126.0->crewai_tools) (2.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.22->crewai_tools) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.22->crewai_tools) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.4.22->crewai_tools) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=0.4.22->crewai_tools) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai_tools) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai_tools) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai_tools) (0.55b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai_tools) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.22->crewai_tools) (3.8.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai_tools) (2025.2)
# Requirement already satisfied: pdfminer.six==20250506 in ./.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai>=0.126.0->crewai_tools) (20250506)
# Requirement already satisfied: Pillow>=9.1 in ./.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai>=0.126.0->crewai_tools) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in ./.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai>=0.126.0->crewai_tools) (4.30.1)
# Requirement already satisfied: nodeenv>=1.6.0 in ./.venv/lib/python3.12/site-packages (from pyright>=1.1.350->crewai_tools) (1.9.1)
# Requirement already satisfied: ipython>=5.3.0 in ./.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai>=0.126.0->crewai_tools) (9.3.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in ./.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai>=0.126.0->crewai_tools) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in ./.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai>=0.126.0->crewai_tools) (3.5)
# ...
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in ./.venv/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (0.3.8)
# Requirement already satisfied: cohere<6.0,>=5.5.6 in ./.venv/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (5.15.0)
# Requirement already satisfied: langchain-experimental<0.4.0,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (0.3.4)
# Requirement already satisfied: pandas>=1.4.3 in ./.venv/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (2.3.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in ./.venv/lib/python3.12/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (0.9.0)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in ./.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (1.11.1)
# Requirement already satisfied: httpx-sse==0.4.0 in ./.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (0.4.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (2.32.4.20250611)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.venv/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./.venv/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (2.9.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./.venv/lib/python3.12/site-packages (from langsmith<0.4.0,>=0.3.18->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (0.23.0)
# Requirement already satisfied: anyio in ./.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm==1.72.0->crewai[tools]) (4.9.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm==1.72.0->crewai[tools]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm==1.72.0->crewai[tools]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.72.0->crewai[tools]) (0.16.0)
# Requirement already satisfied: pytz>=2024.1 in ./.venv/lib/python3.12/site-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in ./.venv/lib/python3.12/site-packages (from mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (1.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.13.3->crewai[tools]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.13.3->crewai[tools]) (0.8.2)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from openai>=1.13.3->crewai[tools]) (1.3.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai[tools]) (1.17.0)
# Requirement already satisfied: monotonic>=1.5 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai[tools]) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai[tools]) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in ./.venv/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai[tools]) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.31.0->crewai-tools~=0.47.1->crewai[tools]) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai[tools]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai[tools]) (2.19.1)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (1.1.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in ./.venv/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai[tools]) (0.45.3)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm==1.72.0->crewai[tools]) (3.23.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in ./.venv/lib/python3.12/site-packages (from instructor>=1.3.3->crewai[tools]) (0.16)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai[tools]) (1.5.4)
# Requirement already satisfied: google-auth>=1.0.1 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in ./.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai[tools]) (0.6.1)
# Requirement already satisfied: deprecation in ./.venv/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai-tools~=0.47.1->crewai[tools]) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in ./.venv/lib/python3.12/site-packages (from lancedb>=0.5.4->crewai-tools~=0.47.1->crewai[tools]) (20.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai[tools]) (0.1.2)
# Requirement already satisfied: et-xmlfile in ./.venv/lib/python3.12/site-packages (from openpyxl>=3.1.5->crewai[tools]) (2.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai[tools]) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai[tools]) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai[tools]) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.30.0->crewai[tools]) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai[tools]) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai[tools]) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai[tools]) (0.55b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai[tools]) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in ./.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai[tools]) (3.8.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (2025.2)
# Requirement already satisfied: pdfminer.six==20250506 in ./.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai[tools]) (20250506)
# Requirement already satisfied: Pillow>=9.1 in ./.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai[tools]) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in ./.venv/lib/python3.12/site-packages (from pdfplumber>=0.11.4->crewai[tools]) (4.30.1)
# Requirement already satisfied: nodeenv>=1.6.0 in ./.venv/lib/python3.12/site-packages (from pyright>=1.1.350->crewai-tools~=0.47.1->crewai[tools]) (1.9.1)
# Requirement already satisfied: ipython>=5.3.0 in ./.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai[tools]) (9.3.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in ./.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai[tools]) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in ./.venv/lib/python3.12/site-packages (from pyvis>=0.3.2->crewai[tools]) (3.5)
# Requirement already satisfied: decorator in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (3.0.51)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./.venv/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (5.14.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.7.0)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in ./.venv/lib/python3.12/site-packages (from qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (2.10.1)
# Requirement already satisfied: h2<5,>=3 in ./.venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (4.2.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in ./.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in ./.venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai<0.2.0,>=0.1.54->embedchain>=0.1.114->crewai-tools~=0.47.1->crewai[tools]) (4.1.0)
# Requirement already satisfied: httptools>=0.6.3 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai[tools]) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai[tools]) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai[tools]) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai[tools]) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in ./.venv/lib/python3.12/site-packages (from coloredlogs->onnxruntime==1.22.0->crewai[tools]) (10.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->crewai[tools]) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy->onnxruntime==1.22.0->crewai[tools]) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from crewai_tools import MySQLSearchTool

# Initialize the tool with the database URI and the target table name
tool = MySQLSearchTool(
    db_uri='mysql://kavin:Ispl@2025@192.168.1.197:3306/kavin',
    table_name='sales'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       1 from crewai_tools import MySQLSearchTool
#       3 # Initialize the tool with the database URI and the target table name
# ----> 4 tool = MySQLSearchTool(
#       5     db_uri='mysql://kavin:Ispl@2025@192.168.1.197:3306/kavin',
#       6     table_name='sales'
#       7 )
#
# File ~/Desktop/Frappe_bot/.venv/lib/python3.12/site-packages/crewai_tools/tools/mysql_search_tool/mysql_search_tool.py:27, in MySQLSearchTool.__init__(self, table_name, **kwargs)
#      25 super().__init__(**kwargs)
#      26 kwargs["data_type"] = "mysql"
# ---> 27 kwargs["loader"] = MySQLLoader(config=dict(url=self.db_uri))
#      28 self.add(table_name)
#      29 self.description = f"A tool that can be used to semantic search a query the {table_name} database table's content."
#
# File ~/Desktop/Frappe_bot/.venv/lib/python3.12/site-packages/embedchain/loaders/mysql.py:23, in MySQLLoader.__init__(self, config)
#      21 self.connection = None
#      22 self.cursor = None
# ---> 23 self._setup_loader(config=config)
#
# File ~/Desktop/Frappe_bot/.venv/lib/python3.12/site-packages/embedchain/loaders/mysql.py:34, in MySQLLoader._setup_loader(self, config)
#      29     raise ImportError(
#      30         "Unable to import required packages for MySQL loader. Run `pip install --upgrade 'embedchain[mysql]'`."  # noqa: E501
#      31     ) from e
#      33 try:
# ---> 34     self.connection = sqlconnector.connection.MySQLConnection(**config)
#      35     self.cursor = self.connection.cursor()
#      36 except (sqlconnector.Error, IOError) as err:
#
# File ~/Desktop/Frappe_bot/.venv/lib/python3.12/site-packages/mysql/connector/connection.py:180, in MySQLConnection.__init__(self, **kwargs)
#     178 if kwargs:
#     179     try:
# --> 180         self.connect(**kwargs)
#     181     except Exception:
#     182         # Tidy-up underlying socket on failure
#     183         self.close()
#
# File ~/Desktop/Frappe_bot/.venv/lib/python3.12/site-packages/mysql/connector/abstracts.py:1357, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1355 # open connection using the default charset id
#    1356 if kwargs:
# -> 1357     self.config(**kwargs)
#    1359 self.disconnect()
#    1360 self._open_connection()
#
# File ~/Desktop/Frappe_bot/.venv/lib/python3.12/site-packages/mysql/connector/abstracts.py:697, in MySQLConnectionAbstract.config(self, **kwargs)
#     695     DEFAULT_CONFIGURATION[key]
#     696 except KeyError:
# --> 697     raise AttributeError(f"Unsupported argument '{key}'") from None
#     698 # SSL Configuration
#     699 if key.startswith("ssl_"):
#
# AttributeError: Unsupported argument 'url'
